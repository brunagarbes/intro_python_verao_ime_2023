# %%
pip install plotnine # pacote que permite usarmos o paccote Ggplot2 no Python
# Out:
# Collecting plotnine
#   Downloading plotnine-0.10.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 2.6 MB/s eta 0:00:01
# Collecting matplotlib>=3.5.0
#   Downloading matplotlib-3.6.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 4.2 MB/s eta 0:00:01
# Collecting statsmodels>=0.13.2
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 2.2 MB/s eta 0:00:01
# Collecting scipy>=1.5.0
#   Downloading scipy-1.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      |████████████████████████████████| 34.4 MB 7.8 MB/s eta 0:00:012
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.19.0 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from plotnine) (1.24.1)
# Requirement already satisfied: pandas>=1.3.5 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from plotnine) (1.5.3)
# Collecting mizani>=0.8.1
#   Downloading mizani-0.8.1-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.1 MB/s  eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 6.9 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Requirement already satisfied: packaging>=20.0 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (23.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      |████████████████████████████████| 299 kB 5.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (2.8.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting palettable
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from pandas>=1.3.5->plotnine) (2022.7.1)
# Requirement already satisfied: six in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, scipy, patsy, palettable, matplotlib, statsmodels, mizani, plotnine
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.3 mizani-0.8.1 palettable-3.3.0 patsy-0.5.3 pillow-9.4.0 plotnine-0.10.1 pyparsing-3.0.9 scipy-1.10.0 statsmodels-0.13.5
# WARNING: You are using pip version 21.1.2; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (3.6.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.19 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.1.2; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gapminder
# Out:
# Collecting gapminder
#   Downloading gapminder-0.1-py3-none-any.whl (32 kB)
# Requirement already satisfied: pandas in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from gapminder) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from pandas->gapminder) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from pandas->gapminder) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from pandas->gapminder) (1.24.1)
# Requirement already satisfied: six>=1.5 in /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->gapminder) (1.16.0)
# Installing collected packages: gapminder
# Successfully installed gapminder-0.1
# WARNING: You are using pip version 21.1.2; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from plotnine import *
from plotnine.data import mpg
from plotnine.data import mtcars
from gapminder import gapminder
# %matplotlib inline
# magic command que ajuda a plotar gráficos no jupyter notebook
# https://towardsdatascience.com/top-8-magic-commands-in-jupyter-notebook-c1582e813560

# %% [markdown]
# A [documentacão](https://plotnine.readthedocs.io/en/stable/index.html) da biblioteca Plotnine é bastante interessante de se ler!

# %%
dados = pd.DataFrame({"var_x": list(range(4)),
                      "var_y": list(range(2,9,2)),
                      "var_grupo": ["a", "a","a", "b"]})
dados
# Out:
#    var_x  var_y var_grupo
# 0      0      2         a
# 1      1      4         a
# 2      2      6         a
# 3      3      8         b

# %%
#exemplo
ggplot(dados)
# Out:
# <ggplot: (8737418527729)>

# %%
#exemplo
ggplot(dados, aes(x = "var_x", y = "var_y"))
# Out:
# <ggplot: (8737418133953)>

# %%
#exemplo
(ggplot(dados, aes(x = "var_x", y = "var_y")) +
  geom_point())
# Out:
# <ggplot: (8737418045154)>

# %%
(ggplot(dados) +
  geom_point(aes(x = "var_x", y = "var_y",color = "var_grupo"))+
  facet_grid("~var_grupo"))
# Out:
# <ggplot: (8737418803484)>

# %%
(ggplot(dados, aes(x = "var_x", y = "var_y",color = "var_grupo")) +
  geom_point()+
  facet_grid("~var_grupo"))
# Out:
# <ggplot: (8737417716511)>

# %%
(ggplot(dados, aes(x = "var_x", y = "var_y",color = "var_grupo", label = "var_x")) +
  geom_label()+
  facet_grid("~var_grupo"))
# Out:
# <ggplot: (8737417096668)>

# %%
(ggplot(dados, aes(x = "var_x", y = "var_y",color = "var_grupo", label = "var_x")) +
  geom_label()+
  facet_grid("~var_grupo")+
  theme_dark()
 )
# Out:
# <ggplot: (8737417093277)>

# %% [markdown]
# ## Base de dados Cars93

# %%
cars93 = pd.read_csv("../dados/Cars93.csv")
cars93.describe()
# cars93.head(10)
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count  93.000000  93.000000  93.000000  93.000000    93.000000   93.000000
# mean   17.125806  19.509677  21.898925  22.365591    29.086022    2.667742
# std     8.746029   9.659430  11.030457   5.619812     5.331726    1.037363
# min     6.700000   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%    10.800000  12.200000  14.700000  18.000000    26.000000    1.800000
# 50%    14.700000  17.700000  19.600000  21.000000    28.000000    2.400000
# 75%    20.300000  23.300000  25.300000  25.000000    31.000000    3.300000
# max    45.400000  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   93.000000    93.000000     93.000000           93.000000   93.000000
# mean   143.827957  5280.645161   2332.204301           16.664516    5.086022
# std     52.374410   596.731690    496.506525            3.279370    1.038979
# min     55.000000  3800.000000   1320.000000            9.200000    2.000000
# 25%    103.000000  4800.000000   1985.000000           14.500000    4.000000
# 50%    140.000000  5200.000000   2340.000000           16.400000    5.000000
# 75%    170.000000  5750.000000   2565.000000           18.800000    6.000000
# max    300.000000  6500.000000   3755.000000           27.000000    8.000000
#
#            Length   Wheelbase      Width  Turn.circle  Rear.seat.room  \
# count   93.000000   93.000000  93.000000    93.000000       91.000000
# mean   183.204301  103.946237  69.376344    38.956989       27.829670
# std     14.602382    6.819674   3.778986     3.223265        2.989072
# min    141.000000   90.000000  60.000000    32.000000       19.000000
# 25%    174.000000   98.000000  67.000000    37.000000       26.000000
# 50%    183.000000  103.000000  69.000000    39.000000       27.500000
# 75%    192.000000  110.000000  72.000000    41.000000       30.000000
# max    219.000000  119.000000  78.000000    45.000000       36.000000
#
#        Luggage.room       Weight
# count     82.000000    93.000000
# mean      13.890244  3072.903226
# std        2.997967   589.896510
# min        6.000000  1695.000000
# 25%       12.000000  2620.000000
# 50%       14.000000  3040.000000
# 75%       15.000000  3525.000000
# max       22.000000  4105.000000

# %% [markdown]
# ## Histograma

# %%
## Histograma
ggplot(cars93, aes(x = "Horsepower")) # precisamos especificar o tipo de gráfico
# Out:
# <ggplot: (8737417373323)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram())
# Out:
# /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages/plotnine/stats/stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 9'. Pick better value with 'binwidth'.
# <ggplot: (8737416991802)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10))
# Out:
# <ggplot: (8737417439988)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10, color = "black", fill = "purple")
 )
# Out:
# <ggplot: (8737417950215)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10, color = "black", fill = "purple") +
 theme_bw()
 )
# Out:
# <ggplot: (8737425073981)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(binwidth =10, color = "black", fill = "purple") +
 theme_bw() +
 labs(x = "Nome eixo x",
      y = "Nome eiixo y",
      title = "Título",
      caption="Fonte de Dados")
 )
# Out:
# <ggplot: (8737417136050)>

# %%
## Histograma
(ggplot(cars93, aes(x = "Horsepower")) +
 geom_histogram(bins =10, color = "black", fill = "purple") +
 theme_bw() +
 labs(x = "Horsepower",
      y = "Frequência",
      title = "Potência")
 )
# Out:
# <ggplot: (8737424961880)>

# %% [markdown]
# ## Gráfico de barras

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar()
 )
# Out:
# <ggplot: (8737418398711)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue")
 )
# Out:
# <ggplot: (8737424984739)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro")
 )
# Out:
# <ggplot: (8737433008589)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal()
 )
# Out:
# <ggplot: (8737418451854)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type")) +
 geom_bar(fill = "darkblue") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 facet_grid("~AirBags")
 )
# Out:
# <ggplot: (8737418760310)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) + # cor das colunas tipo de airbag
 geom_bar(position = "dodge", # coloca colunas lado a lado
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal()
 )
# Out:
# <ggplot: (8737416690038)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "dodge",
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1)
 )
# Out:
# <ggplot: (8737416706311)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "fill", # empilhado em 100%
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1)
 )
# Out:
# <ggplot: (8737418062029)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "stack", # empilhadado com base na freq. absoluta
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1)
 )
# Out:
# <ggplot: (8737433065840)>

# %%
## Gráfico de Barras
(ggplot(cars93, aes(x = "Type", fill = "AirBags")) +
 geom_bar(position = "stack", # empilhadado com base na freq. absoluta
          color = "black") +
 labs(x = "Tipo de carro",
      y = "Contagem",
      title = "Tipo de carro") +
 theme_minimal() +
 scale_fill_brewer(palette = "Purples",
                   direction = 1) +
 coord_flip() # inverte eixos
 )
# Out:
# <ggplot: (8737416724797)>

# %% [markdown]
# ## Base de dados HairEyeColor

# %%
hair = pd.read_csv("../dados/HairEyeColor.csv")
hair.describe()
hair.head(10)
# Out:
#    Unnamed: 0   Hair    Eye   Sex  Freq
# 0           1  Black  Brown  Male    32
# 1           2  Brown  Brown  Male    53
# 2           3    Red  Brown  Male    10
# 3           4  Blond  Brown  Male     3
# 4           5  Black   Blue  Male    11
# 5           6  Brown   Blue  Male    50
# 6           7    Red   Blue  Male    10
# 7           8  Blond   Blue  Male    30
# 8           9  Black  Hazel  Male    10
# 9          10  Brown  Hazel  Male    25

# %%
# Transforma dado em categoria
hair['Genero'] = hair['Sex'].astype('category')
hair.head()
# Out:
#    Unnamed: 0   Hair    Eye   Sex  Freq Genero
# 0           1  Black  Brown  Male    32   Male
# 1           2  Brown  Brown  Male    53   Male
# 2           3    Red  Brown  Male    10   Male
# 3           4  Blond  Brown  Male     3   Male
# 4           5  Black   Blue  Male    11   Male

# %% [markdown]
# ## Box-plot

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  fill = "Sex")) +
 theme_minimal() +
 geom_boxplot()
)
# Out:
# <ggplot: (8737416814240)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot() +
 scale_x_discrete(labels = ["Homem", "Mulher"]) + # no R c()
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"]) # passamos uma lista do jeito do Python
)
# Out:
# <ggplot: (8737433196560)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) +
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"])
)
# Out:
# <ggplot: (8737416884339)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) +
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"])
)

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot() +
 geom_dotplot(binaxis = 'y',
              stackdir = 'center',
              dotsize = 1,
              binwidth = 2) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) +
 xlab("Sexo") +
 ylab("Frequencia") +
 scale_color_manual(values = ["darkblue", "red"])
)
# Out:
# <ggplot: (8737433216052)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  color = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) + #cores padrao do ggplot2
 labs(title = "Boxplot",
      x = "Sexo",
      y = "Frequência")
)
# Out:
# <ggplot: (8737417348057)>

# %%
(ggplot(hair, aes(x = "Genero",
                  y = "Freq",
                  fill = "Sex")) + # cor da caixa
 theme_minimal() +
 geom_boxplot(outlier_colour = "black", # no R é outlier.colour
              outlier_shape = 8,
              outlier_size = 4) +
 scale_x_discrete(labels = ["Homem", "Mulher"]) + #cores padrao do ggplot2
 labs(title = "Boxplot",
      x = "Sexo",
      y = "Frequência") +
 scale_fill_manual(values = ["darkblue", "red"])
)
# Out:
# <ggplot: (8737416962949)>

# %%
# lembra que importamos no comeco da aula?
mtcars.describe()
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
(ggplot(mtcars, aes(x="mpg", y="drat")) +
 geom_point()
)
# Out:
# <ggplot: (8737416626429)>

# %%
(ggplot(mtcars, aes(x="mpg", y="drat")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      caption = "Base de dados mtcars")
)
# Out:
# <ggplot: (8737424759974)>

# %%
(ggplot(mtcars, aes(x="mpg", y="drat", size="carb")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      caption = "Base de dados mtcars")
)
# Out:
# <ggplot: (8737424738452)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat",
                    size="carb",
                    colour="cyl")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars")
)
# Out:
# <ggplot: (8737416743223)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat",
                    size="carb",
                    colour="cyl")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 geom_vline(xintercept=20, color="red") # no R é col="red"
)
# Out:
# <ggplot: (8737417799927)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat",
                    size="carb",
                    colour="cyl")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 geom_hline(yintercept=4, color="red") # no R é col="red"
)
# Out:
# <ggplot: (8737416714996)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 geom_smooth(method = "lm", se = False, color = "red") # No R é FALSE
)
# Out:
# <ggplot: (8793644655981)>

# %%
(ggplot(mtcars, aes(x="mpg",
                    y="drat")) +
 geom_point() +
 theme_classic() +
 labs(title = "Gráfico de Dispersão",
      x = "MPG",
      y = "Drat",
      colour = "Cilindros",
      caption = "Base de dados mtcars") +
 geom_smooth(method = "lm", se = True, color = "red") # No R é FALSE
)
# Out:
# <ggplot: (8793641579569)>

# %%
## Base de dados GapMinder

# %%
gapminder.describe()
gapminder.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
(ggplot(gapminder, aes("gdpPercap", "lifeExp")) +
 geom_point()
 )
# Out:
# <ggplot: (8737418781163)>

# %%
(ggplot(gapminder, aes(x ="gdpPercap",
                       y="lifeExp",
                       size= "pop")) +
 geom_point()
 )
# Out:
# <ggplot: (8737424706720)>

# %%
(ggplot(gapminder, aes(x ="gdpPercap",
                       y="lifeExp",
                       size= "pop",
                       colour = "country")) +
 geom_point(show_legend = False, alpha = 0.7)
 )
# Out:
# <ggplot: (8737417477075)>

# %%
(ggplot(gapminder, aes(x ="gdpPercap",
                       y="lifeExp",
                       size= "pop",
                       colour = "country")) +
 geom_point(show_legend = False, alpha = 0.7) +
 scale_x_log10() +
 labs(x = "PIB per capita", y = "PIB per capita")
 )
# Out:
# <ggplot: (8737417037502)>

# %%
#vamos criar uma variável para guardar só os dados de 2007
gapminder_2007 = gapminder[gapminder["year"]== 2007]
gapminder_2007.head()
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 11  Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23      Albania    Europe  2007   76.423   3600523   5937.029526
# 35      Algeria    Africa  2007   72.301  33333216   6223.367465
# 47       Angola    Africa  2007   42.731  12420476   4797.231267
# 59    Argentina  Americas  2007   75.320  40301927  12779.379640

# %%
(ggplot(gapminder_2007,
       aes(x = "gdpPercap", y = "lifeExp",
           color = "continent", size = "pop")) +
  geom_point() +
  scale_x_log10() +
  labs(title = "Health and wealth grow together",
       x = "Wealth (GDP per capita)",
       y = "Health (life expectancy)",
       color = "Continent",
       size = "Population",
       caption = "Source: The Gapminder Project - Data from 2007"))
# Out:
# <ggplot: (8737432990142)>

# %% [markdown]
# ## Customizando o seu gráfico
#
# Os elementos visuais do nosso gráficos não relacionados a representacão dos nossos dados podem ser customizados com comando theme(). [Neste artigo](https://cmdlinetips.com/2021/05/tips-to-customize-text-color-font-size-in-ggplot2-with-element_text/) vários elementos textuais são explorados. Neste [outro artigo](https://cmdlinetips.com/2021/06/ggplot2-theme-element_blank-tips/) o chamado element_blank é explorado (usamos ele para não plotar alguns elementos do gráfico). Já o artigo [deste link](https://cmdlinetips.com/2021/06/7-tips-to-customize-rectangle-elements-in-ggplot2-element_rect/) explora os elementos retangulares do gráfico como borda do painel do gráfico e por fim [este artigo](https://cmdlinetips.com/2021/05/tips-to-customize-lines-in-ggplot2-with-element_line/) mostra como customizar todas as linhas que não representam dados no nosso gráfico.
#
# O texto é voltado para o Ggplot2 no R mas podemos muito bem utilizar para o Plotnine do Python!

# %%
 p = (ggplot(gapminder_2007,
       aes(x = "gdpPercap", y = "lifeExp",
           color = "continent", size = "pop")) +
  geom_point() +
  scale_x_log10() +
  labs(title = "Health and wealth grow together",
       x = "Wealth (GDP per capita)",
       y = "Health (life expectancy)",
       color = "Continent",
       size = "Population",
       caption = "Source: The Gapminder Project - Data from 2007"))

p + theme(axis_title_x = element_text(size=16,
                                      color="purple",
                                      face="bold",
                                      angle=0))
# Out:
# <ggplot: (8737418382710)>

# %% [markdown]
# ## Salvando um gráfico

# %% [markdown]
# Para salvar, nós salvamos nosso gráfico em uma variável e utilizamos o comando *ggsave*
# Essa funcão aceita vários parâmetros para salvar o gráfico em vários formatos e tamanhos. Vale a pena olhar a sua [documentacao](https://plotnine.readthedocs.io/en/stable/generated/plotnine.ggplot.html)

# %%
graph = (ggplot(gapminder_2007,
       aes(x = "gdpPercap", y = "lifeExp",
           color = "continent", size = "pop")) +
  geom_point() +
  scale_x_log10() +
  labs(title = "Health and wealth grow together",
       x = "Wealth (GDP per capita)",
       y = "Health (life expectancy)",
       color = "Continent",
       size = "Population",
       caption = "Source: The Gapminder Project - Data from 2007"))

ggsave(plot = graph, filename = "gapminder_graph.png", path = "../img")
# Out:
# /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/garbes/Documentos/projetos/intro_python_verao_ime_2023/venv/lib/python3.9/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: ../img/gapminder_graph.png
